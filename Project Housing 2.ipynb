# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
housing_data=pd.read_csv("D:\Data\Capstone Project\P1\HousingData.csv")

# %%
housing_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
print (len(housing_data.index))
print (len(housing_data.columns))
# Out:
# 506
# 14

# %%
housing_data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
dec=housing_data.describe().T
dec.to_csv("D:\Data\Capstone Project\P1\HousingDatadec.csv")
dec
# Out:
#          count        mean         std        min         25%         50%  \
# CRIM     486.0    3.611874    8.720192    0.00632    0.081900    0.253715
# ZN       486.0   11.211934   23.388876    0.00000    0.000000    0.000000
# INDUS    486.0   11.083992    6.835896    0.46000    5.190000    9.690000
# CHAS     486.0    0.069959    0.255340    0.00000    0.000000    0.000000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.538000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.208500
# AGE      486.0   68.518519   27.999513    2.90000   45.175000   76.800000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.207450
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.000000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.000000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.050000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.440000
# ...

# %%
housing_data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
housing_data.T
# Out:
#                0          1          2          3          4          5    \
# CRIM       0.00632    0.02731    0.02729    0.03237    0.06905    0.02985
# ZN        18.00000    0.00000    0.00000    0.00000    0.00000    0.00000
# INDUS      2.31000    7.07000    7.07000    2.18000    2.18000    2.18000
# CHAS       0.00000    0.00000    0.00000    0.00000    0.00000    0.00000
# NOX        0.53800    0.46900    0.46900    0.45800    0.45800    0.45800
# RM         6.57500    6.42100    7.18500    6.99800    7.14700    6.43000
# AGE       65.20000   78.90000   61.10000   45.80000   54.20000   58.70000
# DIS        4.09000    4.96710    4.96710    6.06220    6.06220    6.06220
# RAD        1.00000    2.00000    2.00000    3.00000    3.00000    3.00000
# TAX      296.00000  242.00000  242.00000  222.00000  222.00000  222.00000
# PTRATIO   15.30000   17.80000   17.80000   18.70000   18.70000   18.70000
# B        396.90000  396.90000  392.83000  394.63000  396.90000  394.12000
# ...

# %%
housing_data1=housing_data

# %%
housing_data1['CRIM'].fillna((housing_data1['CRIM'].mean()),inplace=True)
housing_data1['ZN'].fillna((housing_data1['ZN'].mean()),inplace=True)
housing_data1['INDUS'].fillna((housing_data1['INDUS'].mean()),inplace=True)
housing_data1['CHAS'].fillna((housing_data1['CHAS'].mean()),inplace=True)
housing_data1['LSTAT'].fillna((housing_data1['LSTAT'].mean()),inplace=True)
housing_data1['AGE'].fillna((housing_data1['AGE'].mean()),inplace=True)
housing_data1
# Out:
#          CRIM    ZN  INDUS      CHAS    NOX     RM         AGE     DIS  RAD  \
# 0     0.00632  18.0   2.31  0.000000  0.538  6.575   65.200000  4.0900    1
# 1     0.02731   0.0   7.07  0.000000  0.469  6.421   78.900000  4.9671    2
# 2     0.02729   0.0   7.07  0.000000  0.469  7.185   61.100000  4.9671    2
# 3     0.03237   0.0   2.18  0.000000  0.458  6.998   45.800000  6.0622    3
# 4     0.06905   0.0   2.18  0.000000  0.458  7.147   54.200000  6.0622    3
# 5     0.02985   0.0   2.18  0.000000  0.458  6.430   58.700000  6.0622    3
# 6     0.08829  12.5   7.87  0.069959  0.524  6.012   66.600000  5.5605    5
# 7     0.14455  12.5   7.87  0.000000  0.524  6.172   96.100000  5.9505    5
# 8     0.21124  12.5   7.87  0.000000  0.524  5.631  100.000000  6.0821    5
# 9     0.17004  12.5   7.87  0.069959  0.524  6.004   85.900000  6.5921    5
# 10    0.22489  12.5   7.87  0.000000  0.524  6.377   94.300000  6.3467    5
# ...

# %%
housing_data1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
housing_data1.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
plt.boxplot(housing_data1["CRIM"])
plt.show()

# %%
plt.boxplot(housing_data1["ZN"])
plt.show()

# %%
plt.boxplot(housing_data1["INDUS"])
plt.show()

# %%
plt.boxplot(housing_data1["CHAS"])
plt.show()

# %%
plt.boxplot(housing_data1["NOX"])
plt.show()

# %%
plt.boxplot(housing_data1["RM"])
plt.show()

# %%
plt.boxplot(housing_data1["AGE"])
plt.show()

# %%
plt.boxplot(housing_data1["DIS"])
plt.show()

# %%
plt.boxplot(housing_data1["RAD"])
plt.show()

# %%
plt.boxplot(housing_data1["TAX"])
plt.show()

# %%
plt.boxplot(housing_data1["PTRATIO"])
plt.show()

# %%
plt.boxplot(housing_data1["B"])
plt.show()

# %%
plt.boxplot(housing_data1["LSTAT"])
plt.show()

# %%
plt.boxplot(housing_data1["MEDV"])
plt.show()

# %%
# %matplotlib inline

# %%
housing_data1.hist(bins=10,figsize=(9,10),grid=False);
plt.show()

# %%
housing_data1["AGE_Log"]=np.log(housing_data1["AGE"])
housing_data1["AGE_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["B_Log"]=np.log(housing_data1["B"])
housing_data1["B_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["CRIM_Log"]=np.log(housing_data1["CRIM"])
housing_data1["CRIM_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["DIS_Log"]=np.log(housing_data1["DIS"])
housing_data1["DIS_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["INDUS_Log"]=np.log(housing_data1["INDUS"])
housing_data1["INDUS_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["LSTAT_Log"]=np.log(housing_data1["LSTAT"])
housing_data1["LSTAT_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["MEDV_Log"]=np.log(housing_data1["MEDV"])
housing_data1["MEDV_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["NOX_Log"]=np.log(housing_data1["NOX"])
housing_data1["NOX_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["PTRATIO_Log"]=np.log(housing_data1["PTRATIO"])
housing_data1["PTRATIO_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["RAD_Log"]=np.log(housing_data1["RAD"])
housing_data1["RAD_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["RM_Log"]=np.log(housing_data1["RM"])
housing_data1["RM_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1["TAX_Log"]=np.log(housing_data1["TAX"])
housing_data1["TAX_Log"].hist(bins=10,figsize=(5,6),grid=False);

# %%
housing_data1.head(10)
# Out:
#       CRIM    ZN  INDUS      CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31  0.000000  0.538  6.575   65.2  4.0900    1  296
# 1  0.02731   0.0   7.07  0.000000  0.469  6.421   78.9  4.9671    2  242
# 2  0.02729   0.0   7.07  0.000000  0.469  7.185   61.1  4.9671    2  242
# 3  0.03237   0.0   2.18  0.000000  0.458  6.998   45.8  6.0622    3  222
# 4  0.06905   0.0   2.18  0.000000  0.458  7.147   54.2  6.0622    3  222
# 5  0.02985   0.0   2.18  0.000000  0.458  6.430   58.7  6.0622    3  222
# 6  0.08829  12.5   7.87  0.069959  0.524  6.012   66.6  5.5605    5  311
# 7  0.14455  12.5   7.87  0.000000  0.524  6.172   96.1  5.9505    5  311
# 8  0.21124  12.5   7.87  0.000000  0.524  5.631  100.0  6.0821    5  311
# 9  0.17004  12.5   7.87  0.069959  0.524  6.004   85.9  6.5921    5  311
#
#      ...     CRIM_Log   DIS_Log  INDUS_Log  LSTAT_Log  MEDV_Log   NOX_Log  \
# 0    ...    -5.064036  1.408545   0.837248   1.605430  3.178054 -0.619897
# ...

# %%
housing_data1.dtypes
# Out:
# CRIM           float64
# ZN             float64
# INDUS          float64
# CHAS           float64
# NOX            float64
# RM             float64
# AGE            float64
# DIS            float64
# RAD              int64
# TAX              int64
# PTRATIO        float64
# B              float64
# LSTAT          float64
# MEDV           float64
# AGE_Log        float64
# B_Log          float64
# CRIM_Log       float64
# DIS_Log        float64
# INDUS_Log      float64
# LSTAT_Log      float64
# MEDV_Log       float64
# NOX_Log        float64
# PTRATIO_Log    float64
# RAD_Log        float64
# RM_Log         float64
# TAX_Log        float64
# dtype: object

# %%
final_df=housing_data1.to_csv("D:\\Data\\Capstone Project\\P1\\final_df.csv")

# %%
final_df=housing_data1

# %%
final_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX    ...     \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296    ...
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242    ...
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242    ...
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222    ...
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222    ...
#
#    CRIM_Log   DIS_Log  INDUS_Log  LSTAT_Log  MEDV_Log   NOX_Log  PTRATIO_Log  \
# 0 -5.064036  1.408545   0.837248   1.605430  3.178054 -0.619897     2.727853
# 1 -3.600502  1.602836   1.955860   2.212660  3.072693 -0.757153     2.879198
# 2 -3.601235  1.602836   1.955860   1.393766  3.546740 -0.757153     2.879198
# 3 -3.430523  1.802073   0.779325   1.078410  3.508556 -0.780886     2.928524
# 4 -2.672924  1.802073   0.779325   2.542816  3.589059 -0.780886     2.928524
#
#     RAD_Log    RM_Log   TAX_Log
# ...

# %%
final_df.drop("CRIM",axis=1, inplace=True)
final_df.drop("INDUS",axis=1, inplace=True)
final_df.drop("NOX",axis=1, inplace=True)
final_df.drop("RM",axis=1, inplace=True)
final_df.drop("AGE",axis=1, inplace=True)
final_df.drop("DIS",axis=1, inplace=True)
final_df.drop("RAD",axis=1, inplace=True)
final_df.drop("TAX",axis=1, inplace=True)
final_df.drop("PTRATIO",axis=1, inplace=True)
final_df.drop("B",axis=1, inplace=True)
final_df.drop("LSTAT",axis=1, inplace=True)
final_df.drop("MEDV",axis=1, inplace=True)

# %%
final_df.head()
# Out:
#      ZN  CHAS   AGE_Log     B_Log  CRIM_Log   DIS_Log  INDUS_Log  LSTAT_Log  \
# 0  18.0   0.0  4.177459  5.983684 -5.064036  1.408545   0.837248   1.605430
# 1   0.0   0.0  4.368181  5.983684 -3.600502  1.602836   1.955860   2.212660
# 2   0.0   0.0  4.112512  5.973377 -3.601235  1.602836   1.955860   1.393766
# 3   0.0   0.0  3.824284  5.977949 -3.430523  1.802073   0.779325   1.078410
# 4   0.0   0.0  3.992681  5.983684 -2.672924  1.802073   0.779325   2.542816
#
#    MEDV_Log   NOX_Log  PTRATIO_Log   RAD_Log    RM_Log   TAX_Log
# 0  3.178054 -0.619897     2.727853  0.000000  1.883275  5.690359
# 1  3.072693 -0.757153     2.879198  0.693147  1.859574  5.488938
# 2  3.546740 -0.757153     2.879198  0.693147  1.971996  5.488938
# 3  3.508556 -0.780886     2.928524  1.098612  1.945624  5.402677
# 4  3.589059 -0.780886     2.928524  1.098612  1.966693  5.402677

# %%
final_df.hist(bins=10,figsize=(9,10),grid=False);
plt.show()

# %%
plt.boxplot(final_df["CRIM_Log"])
plt.show()

# %%
plt.boxplot(final_df["AGE_Log"])
plt.show()

# %%
plt.boxplot(final_df["B_Log"])
plt.show()

# %%
plt.boxplot(final_df["CHAS"])
plt.show()

# %%
plt.boxplot(final_df["DIS_Log"])
plt.show()

# %%
plt.boxplot(final_df["INDUS_Log"])
plt.show()

# %%
plt.boxplot(final_df["LSTAT_Log"])
plt.show()

# %%
plt.boxplot(final_df["MEDV_Log"])
plt.show()

# %%
plt.boxplot(final_df["NOX_Log"])
plt.show()

# %%
plt.boxplot(final_df["PTRATIO_Log"])
plt.show()

# %%
plt.boxplot(final_df["RAD_Log"])
plt.show()

# %%
plt.boxplot(final_df["RM_Log"])
plt.show()

# %%
plt.boxplot(final_df["ZN"])
plt.show()

# %%
plt.boxplot(final_df["TAX_Log"])
plt.show()

# %%
final_df.corr()
# Out:
#                    ZN      CHAS   AGE_Log     B_Log  CRIM_Log   DIS_Log  \
# ZN           1.000000 -0.036147 -0.494066  0.130165 -0.473096  0.570242
# CHAS        -0.036147  1.000000  0.081667  0.050029  0.026560 -0.077835
# AGE_Log     -0.494066  0.081667  1.000000 -0.173571  0.516416 -0.672309
# B_Log        0.130165  0.050029 -0.173571  1.000000 -0.376512  0.247961
# CRIM_Log    -0.473096  0.026560  0.516416 -0.376512  1.000000 -0.708714
# DIS_Log      0.570242 -0.077835 -0.672309  0.247961 -0.708714  1.000000
# INDUS_Log   -0.633066  0.075592  0.501269 -0.254687  0.686323 -0.720590
# LSTAT_Log   -0.475391 -0.065597  0.524059 -0.266262  0.540887 -0.507401
# MEDV_Log     0.365604  0.163198 -0.387643  0.343420 -0.540086  0.405721
# NOX_Log     -0.553389  0.067878  0.659240 -0.290522  0.772407 -0.860018
# PTRATIO_Log -0.401020 -0.103921  0.207669 -0.168481  0.320229 -0.215174
# RAD_Log     -0.342578  0.019750  0.372622 -0.360548  0.820023 -0.542112
# ...

# %%
import statsmodels.api as sm
# Out:
# C:\Users\Deepak Spartan\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
Y=final_df["MEDV_Log"]
X=final_df[["INDUS_Log","NOX_Log","AGE_Log","RAD_Log","TAX_Log","CRIM_Log","ZN","RM_Log","CHAS","DIS_Log","PTRATIO_Log","LSTAT_Log","B_Log"]]
result=sm.OLS(Y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               MEDV_Log   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     6714.
# Date:                Mon, 10 Sep 2018   Prob (F-statistic):               0.00
# Time:                        21:36:14   Log-Likelihood:                 26.847
# No. Observations:                 506   AIC:                            -27.69
# Df Residuals:                     493   BIC:                             27.25
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# INDUS_Log      -0.0246      0.025     -0.977      0.329      -0.074       0.025
# ...

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
Y_pred = lm.predict(X_test)
lm.score(X_train, y_train)
# Out:
# 0.75211456718509606

# %%
lm.score(X_test,y_test)
# Out:
# 0.74227383201646857

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#              Coeffecient
# INDUS_Log      -0.033009
# NOX_Log        -0.259944
# AGE_Log        -0.001924
# RAD_Log         0.069706
# TAX_Log        -0.147514
# CRIM_Log       -0.027890
# ZN             -0.001602
# RM_Log          0.519932
# CHAS            0.145172
# DIS_Log        -0.120792
# PTRATIO_Log    -0.592060
# LSTAT_Log      -0.377012
# B_Log           0.062226

# %%
Predictions = lm.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, Predictions))
print('MSE:', metrics.mean_squared_error(y_test, Predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, Predictions)))
# Out:
# MAE: 0.1399968985
# MSE: 0.0396635470918
# RMSE: 0.199157091493

# %%
plt.scatter(y_test,Predictions)
plt.xlabel('Real Price')
plt.ylabel('Predicted Prices')
plt.title( "Real vs Predicted Housing Prices")
# Out:
# Text(0.5,1,'Real vs Predicted Housing Prices')

# %%
sns.distplot((y_test-Predictions),bins=50)
